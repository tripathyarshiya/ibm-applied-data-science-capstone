# %% [markdown]
# # Part 1

# %%
#Import Packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium
#! pip install BeautifulSoup
from bs4 import BeautifulSoup
import requests

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#Extract data from wikipedia
website_url = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
soup = BeautifulSoup(website_url,"lxml")
My_table = soup.find("table",{"class":"wikitable sortable"})
#My_table

# %%
table_data = My_table.tbody.find_all("tr")
table_data[0]
# Out:
# <tr>
# <th>Postcode</th>
# <th>Borough</th>
# <th>Neighbourhood
# </th></tr>

# %%
#Extract column headers
column = [x.text.strip() for x in table_data[0].find_all("th")]
column
# Out:
# ['Postcode', 'Borough', 'Neighbourhood']

# %%
data_table = pd.DataFrame(columns = column)

# %%
#Create basic data table
rows = []
for i in range(1,len(table_data)-1):
    rows = [x.text.strip() for x in table_data[i].find_all("td")]
    data_table.loc[i] = rows

data_table.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 1      M1A      Not assigned      Not assigned
# 2      M2A      Not assigned      Not assigned
# 3      M3A        North York         Parkwoods
# 4      M4A        North York  Victoria Village
# 5      M5A  Downtown Toronto      Harbourfront

# %%
data_table.reset_index(inplace = True)
data_table.head()
# Out:
#    index Postcode           Borough     Neighbourhood
# 0      1      M1A      Not assigned      Not assigned
# 1      2      M2A      Not assigned      Not assigned
# 2      3      M3A        North York         Parkwoods
# 3      4      M4A        North York  Victoria Village
# 4      5      M5A  Downtown Toronto      Harbourfront

# %%
data_table = data_table[data_table["Borough"] != "Not assigned"]
data_table["Neighbourhood"][data_table["Neighbourhood"] == "Not assigned"] = data_table["Borough"]

# %%
# Get postcodes with more than 1 neighbourhood

abc = data_table.pivot_table(index = "Postcode", values = "Neighbourhood", aggfunc = "count")
postcode_more = abc.index[abc["Neighbourhood"] > 1]
postcode_more
# Out:
# Index(['M1B', 'M1C', 'M1E', 'M1K', 'M1L', 'M1M', 'M1N', 'M1P', 'M1R', 'M1T',
#        'M1V', 'M2J', 'M2L', 'M2M', 'M3C', 'M3H', 'M3J', 'M3K', 'M4B', 'M4K',
#        'M4L', 'M4T', 'M4V', 'M4X', 'M5B', 'M5H', 'M5J', 'M5K', 'M5L', 'M5M',
#        'M5P', 'M5R', 'M5S', 'M5T', 'M5V', 'M5X', 'M6A', 'M6H', 'M6J', 'M6K',
#        'M6L', 'M6M', 'M6N', 'M6P', 'M6R', 'M6S', 'M8V', 'M8W', 'M8X', 'M8Y',
#        'M8Z', 'M9B', 'M9C', 'M9M', 'M9R', 'M9V'],
#       dtype='object', name='Postcode')

# %%
#Get postcodes with 1 neighbourhood
postcode_one = abc.index[abc["Neighbourhood"] == 1]
postcode_one
# Out:
# Index(['M1G', 'M1H', 'M1J', 'M1S', 'M1W', 'M1X', 'M2H', 'M2K', 'M2N', 'M2P',
#        'M2R', 'M3A', 'M3B', 'M3L', 'M3M', 'M3N', 'M4A', 'M4C', 'M4E', 'M4G',
#        'M4H', 'M4J', 'M4M', 'M4N', 'M4P', 'M4R', 'M4S', 'M4W', 'M4Y', 'M5A',
#        'M5C', 'M5E', 'M5G', 'M5N', 'M5W', 'M6B', 'M6C', 'M6E', 'M6G', 'M7A',
#        'M7R', 'M7Y', 'M9A', 'M9L', 'M9N', 'M9P', 'M9W'],
#       dtype='object', name='Postcode')

# %%
#Table with more than 1 Neighbourhood
t1 = data_table.loc[data_table.Postcode.isin(postcode_more),:].sort_values(by='Postcode').reset_index(drop=True)
t1
#Table with 1 Neighbourhood
t2 = data_table.loc[data_table.Postcode.isin(postcode_one),:].sort_values(by='Postcode').reset_index(drop=True)
t2
# Out:
#     index Postcode           Borough  \
# 0      53      M1G       Scarborough
# 1      62      M1H       Scarborough
# 2      76      M1J       Scarborough
# 3     180      M1S       Scarborough
# 4     236      M1W       Scarborough
# 5     246      M1X       Scarborough
# 6      63      M2H        North York
# 7      94      M2K        North York
# 8     142      M2N        North York
# 9     154      M2P        North York
# 10    166      M2R        North York
# 11      3      M3A        North York
# 12     14      M3B        North York
# 13    112      M3L        North York
# 14    128      M3M        North York
# 15    143      M3N        North York
# 16      4      M4A        North York
# 17     33      M4C         East York
# 18     47      M4E      East Toronto
# 19     56      M4G         East York
# 20     67      M4H         East York
# 21     82      M4J         East York
# 22    129      M4M      East Toronto
# 23    144      M4N   Central Toronto
# 24    156      M4P   Central Toronto
# 25    168      M4R   Central Toronto
# 26    183      M4S   Central Toronto
# 27    239      M4W  Downtown Toronto
# 28    262      M4Y  Downtown Toronto
# 29      5      M5A  Downtown Toronto
# 30     34      M5C  Downtown Toronto
# 31     48      M5E  Downtown Toronto
# 32     57      M5G  Downtown Toronto
# 33    145      M5N   Central Toronto
# 34    240      M5W  Downtown Toronto
# 35     19      M6B        North York
# 36     35      M6C              York
# 37     49      M6E              York
# 38     58      M6G  Downtown Toronto
# 39      8      M7A  Downtown Toronto
# 40    174      M7R       Mississauga
# 41    265      M7Y      East Toronto
# 42     10      M9A         Etobicoke
# 43    122      M9L        North York
# 44    150      M9N              York
# 45    163      M9P         Etobicoke
# 46    245      M9W         Etobicoke
#
#                                         Neighbourhood
# 0                                              Woburn
# 1                                           Cedarbrae
# 2                                 Scarborough Village
# 3                                           Agincourt
# 4                                     L'Amoreaux West
# 5                                         Upper Rouge
# 6                                   Hillcrest Village
# 7                                     Bayview Village
# 8                                    Willowdale South
# 9                                     York Mills West
# 10                                    Willowdale West
# 11                                          Parkwoods
# 12                                    Don Mills North
# 13                                     Downsview West
# 14                                  Downsview Central
# 15                                Downsview Northwest
# 16                                   Victoria Village
# 17                                   Woodbine Heights
# 18                                        The Beaches
# 19                                            Leaside
# 20                                   Thorncliffe Park
# 21                                       East Toronto
# 22                                    Studio District
# 23                                      Lawrence Park
# 24                                   Davisville North
# 25                                 North Toronto West
# 26                                         Davisville
# 27                                           Rosedale
# 28                               Church and Wellesley
# 29                                       Harbourfront
# 30                                     St. James Town
# 31                                        Berczy Park
# 32                                 Central Bay Street
# 33                                           Roselawn
# 34                    Stn A PO Boxes 25 The Esplanade
# 35                                          Glencairn
# 36                                 Humewood-Cedarvale
# 37                                Caledonia-Fairbanks
# 38                                           Christie
# 39                                       Queen's Park
# 40              Canada Post Gateway Processing Centre
# 41  Business Reply Mail Processing Centre 969 Eastern
# 42                                   Islington Avenue
# 43                                      Humber Summit
# 44                                             Weston
# 45                                          Westmount
# 46                                          Northwest

# %%
#Neighbours List
codes = []
boroughs = []
neighbours = []

for code in postcode_more:
    
    table = t1.loc[t1.Postcode == code, :] # split 't1' to specific table by 'postcode'
    
    code = np.unique(table.Postcode) # extract unique 'postcode' in the column
    codes.append(code[0])
    
    borough = np.unique(table.Borough) # extract unique 'borough' in the column
    boroughs.append(borough[0])
    
    neighbour = table.Neighbourhood.to_list() # extract all 'neighbourhood' & convert to list format
    neighbour = ', '.join(neighbour) # use .join() method to combine each 'neighbourhood' with ", "
    neighbours.append(neighbour)

neighbours
# Out:
# ['Rouge, Malvern',
#  'Port Union, Rouge Hill, Highland Creek',
#  'Guildwood, West Hill, Morningside',
#  'East Birchmount Park, Ionview, Kennedy Park',
#  'Clairlea, Golden Mile, Oakridge',
#  'Scarborough Village West, Cliffside, Cliffcrest',
#  'Cliffside West, Birch Cliff',
#  'Dorset Park, Scarborough Town Centre, Wexford Heights',
#  'Wexford, Maryvale',
#  "Tam O'Shanter, Sullivan, Clarks Corners",
#  "Agincourt North, Steeles East, L'Amoreaux East, Milliken",
#  'Henry Farm, Fairview, Oriole',
#  'York Mills, Silver Hills',
#  'Newtonbrook, Willowdale',
#  'Flemingdon Park, Don Mills South',
#  'Wilson Heights, Downsview North, Bathurst Manor',
#  'Northwood Park, York University',
#  'CFB Toronto, Downsview East',
#  'Woodbine Gardens, Parkview Hill',
#  'Riverdale, The Danforth West',
#  'India Bazaar, The Beaches West',
#  'Summerhill East, Moore Park',
#  'Forest Hill SE, Rathnelly, Summerhill West, Deer Park, South Hill',
#  'St. James Town, Cabbagetown',
#  'Garden District, Ryerson',
#  'Richmond, King, Adelaide',
#  'Toronto Islands, Union Station, Harbourfront East',
#  'Toronto Dominion Centre, Design Exchange',
#  'Victoria Hotel, Commerce Court',
#  'Lawrence Manor East, Bedford Park',
#  'Forest Hill North, Forest Hill West',
#  'Yorkville, The Annex, North Midtown',
#  'University of Toronto, Harbord',
#  'Chinatown, Grange Park, Kensington Market',
#  'Railway Lands, Harbourfront West, Island airport, Bathurst Quay, CN Tower, South Niagara, King and Spadina',
#  'First Canadian Place, Underground city',
#  'Lawrence Heights, Lawrence Manor',
#  'Dovercourt Village, Dufferin',
#  'Little Portugal, Trinity',
#  'Brockton, Parkdale Village, Exhibition Place',
#  'North Park, Downsview, Upwood Park',
#  'Silverthorn, Mount Dennis, Keelesdale, Del Ray',
#  'The Junction North, Runnymede',
#  'High Park, The Junction South',
#  'Parkdale, Roncesvalles',
#  'Swansea, Runnymede',
#  'New Toronto, Mimico South, Humber Bay Shores',
#  'Long Branch, Alderwood',
#  'Old Mill North, Montgomery Road, The Kingsway',
#  "Mimico NE, Kingsway Park South East, Old Mill South, Humber Bay, Sunnylea, Royal York South East, The Queensway East, King's Mill Park",
#  'The Queensway West, Kingsway Park South West, Mimico NW, South of Bloor, Royal York South West',
#  'Princess Gardens, Martin Grove, Islington, Cloverdale, West Deane Park',
#  'Old Burnhamthorpe, Markland Wood, Eringate, Bloordale Gardens',
#  'Emery, Humberlea',
#  'St. Phillips, Richview Gardens, Martin Grove Gardens, Kingsview Village',
#  'Beaumond Heights, Silverstone, Humbergate, Jamestown, Mount Olive, Thistletown, Albion Gardens, South Steeles']

# %%
# a new dataframe for 'Postcode' with > 1 'Neighbourhood'

table_new = pd.DataFrame({'Postcode': codes, 'Borough': boroughs, 'Neighbourhood': neighbours})
table_new.head()
# Out:
#   Postcode      Borough                                Neighbourhood
# 0      M1B  Scarborough                               Rouge, Malvern
# 1      M1C  Scarborough       Port Union, Rouge Hill, Highland Creek
# 2      M1E  Scarborough            Guildwood, West Hill, Morningside
# 3      M1K  Scarborough  East Birchmount Park, Ionview, Kennedy Park
# 4      M1L  Scarborough              Clairlea, Golden Mile, Oakridge

# %%
# combine 'tbl_new' with 't2' (table with single neighbourhood for each postcode) with concat()

new_data = pd.concat([table_new, t2], axis=0).sort_values(by="Postcode").reset_index(drop=True)
new_data.drop("index", axis = 1, inplace = True)
new_data.head()
# Out:
#        Borough                           Neighbourhood Postcode
# 0  Scarborough                          Rouge, Malvern      M1B
# 1  Scarborough  Port Union, Rouge Hill, Highland Creek      M1C
# 2  Scarborough       Guildwood, West Hill, Morningside      M1E
# 3  Scarborough                                  Woburn      M1G
# 4  Scarborough                               Cedarbrae      M1H

# %%
new_data.shape
# Out:
# (103, 3)

# %% [markdown]
# # Part 2

# %%
# import library for Geocoding
! pip install geopy
! pip install geopandas
import geopy
import geopandas
# Out:
# Requirement already satisfied: geopy in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (1.21.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from geopy) (1.50)
# Requirement already satisfied: geopandas in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: pandas in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from geopandas) (0.24.2)
# Requirement already satisfied: fiona in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from geopandas) (1.8.4)
# Requirement already satisfied: shapely in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from geopandas) (1.6.4.post2)
# Requirement already satisfied: pyproj in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from geopandas) (1.9.6)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from pandas->geopandas) (2.8.0)
# Requirement already satisfied: pytz>=2011k in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from pandas->geopandas) (2019.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from pandas->geopandas) (1.16.4)
# Requirement already satisfied: attrs>=17 in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from fiona->geopandas) (19.1.0)
# Requirement already satisfied: click<8,>=4.0 in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from fiona->geopandas) (7.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from fiona->geopandas) (0.5.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from fiona->geopandas) (1.12.0)
# Requirement already satisfied: munch in c:\users\atripathy\appdata\local\continuum\anaconda3\lib\site-packages (from fiona->geopandas) (2.3.2)

# %%
# note: not requirement of assignment

geo_lat = {}
geo_lon = {}

geo = geopy.Nominatim(user_agent="Detector", timeout=20)

for x in np.unique(new_data.Borough):
    
    loc = geo.geocode("{}, Toronto, Ontario".format(x))
    
    geo_lat[x] = loc.latitude
    geo_lon[x] = loc.longitude

# %%
# Checking latitudes and longitudes
geo_lat
# Out:
# {'Central Toronto': 43.6449033,
#  'Downtown Toronto': 43.6563221,
#  'East Toronto': 43.626243,
#  'East York': 43.699971000000005,
#  'Etobicoke': 43.671459150000004,
#  'Mississauga': 43.6668555,
#  'North York': 43.7543263,
#  'Scarborough': 43.773077,
#  'West Toronto': 43.6449033,
#  'York': 43.67910515}

# %%
# Checking latitudes and longitudes
geo_lon
# Out:
# {'Central Toronto': -79.3818364,
#  'Downtown Toronto': -79.3809161,
#  'East Toronto': -79.396962,
#  'East York': -79.33251996261595,
#  'Etobicoke': -79.55249206611668,
#  'Mississauga': -79.5879563,
#  'North York': -79.44911696639593,
#  'Scarborough': -79.257774,
#  'West Toronto': -79.3818364,
#  'York': -79.49118414007154}

# %%
# instruction given by assignment: to extract latitude & longitutde based on "Postcode"
# API failed to search for geo-location for some postcodes.
# will use csv file provided in coursera link instead

geo = geopy.Nominatim(user_agent="Detector", timeout=50)

for x, y in zip(new_data.Postcode[0:5], new_data.Borough[0:5]):
    
    loc = geo.geocode("{}, {}, Toronto, Canada".format(x, y))
    print("{}, {}: latitude {}, longitude {}".format(x, y, loc.latitude, loc.longitude))
# Out:
# M1B, Scarborough: latitude 43.773077, longitude -79.257774
# M1C, Scarborough: latitude 43.773077, longitude -79.257774
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-0c6d98ea55f2> in <module>
#       8
#       9     loc = geo.geocode("{}, {}, Toronto, Canada".format(x, y))
# ---> 10     print("{}, {}: latitude {}, longitude {}".format(x, y, loc.latitude, loc.longitude))
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
# Link provided by coursera link
geo_data = pd.read_csv("http://cocl.us/Geospatial_data")
geo_data.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
geo_df = geo_data.loc[geo_data["Postal Code"].isin(new_data.Postcode.values), :]
print(geo_df.shape)

geo_table = new_data.merge(geo_df, left_on="Postcode", right_on="Postal Code")
geo_table.head()
# Out:
# (103, 3)
#        Borough                           Neighbourhood Postcode Postal Code  \
# 0  Scarborough                          Rouge, Malvern      M1B         M1B
# 1  Scarborough  Port Union, Rouge Hill, Highland Creek      M1C         M1C
# 2  Scarborough       Guildwood, West Hill, Morningside      M1E         M1E
# 3  Scarborough                                  Woburn      M1G         M1G
# 4  Scarborough                               Cedarbrae      M1H         M1H
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %%
geo_table = geo_table[["Postcode", "Borough", "Neighbourhood", "Latitude", "Longitude"]]

# %%
geo_table
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A  Downtown Toronto
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                       Rouge, Malvern  43.806686 -79.194353
# 1               Port Union, Rouge Hill, Highland Creek  43.784535 -79.160497
# 2                    Guildwood, West Hill, Morningside  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6          East Birchmount Park, Ionview, Kennedy Park  43.727929 -79.262029
# 7                      Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 8      Scarborough Village West, Cliffside, Cliffcrest  43.716316 -79.239476
# 9                          Cliffside West, Birch Cliff  43.692657 -79.264848
# 10   Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 11                                   Wexford, Maryvale  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13             Tam O'Shanter, Sullivan, Clarks Corners  43.781638 -79.304302
# 14   Agincourt North, Steeles East, L'Amoreaux East...  43.815252 -79.284577
# 15                                     L'Amoreaux West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                        Henry Farm, Fairview, Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                            York Mills, Silver Hills  43.757490 -79.374714
# 21                             Newtonbrook, Willowdale  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 28     Wilson Heights, Downsview North, Bathurst Manor  43.754328 -79.442259
# 29                     Northwood Park, York University  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 77                            Little Portugal, Trinity  43.647927 -79.419750
# 78        Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 79                  North Park, Downsview, Upwood Park  43.713756 -79.490074
# 80      Silverthorn, Mount Dennis, Keelesdale, Del Ray  43.691116 -79.476013
# 81                       The Junction North, Runnymede  43.673185 -79.487262
# 82                       High Park, The Junction South  43.661608 -79.464763
# 83                              Parkdale, Roncesvalles  43.648960 -79.456325
# 84                                  Swansea, Runnymede  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88        New Toronto, Mimico South, Humber Bay Shores  43.605647 -79.501321
# 89                              Long Branch, Alderwood  43.602414 -79.543484
# 90       Old Mill North, Montgomery Road, The Kingsway  43.653654 -79.506944
# 91   Mimico NE, Kingsway Park South East, Old Mill ...  43.636258 -79.498509
# 92   The Queensway West, Kingsway Park South West, ...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   Princess Gardens, Martin Grove, Islington, Clo...  43.650943 -79.554724
# 95   Old Burnhamthorpe, Markland Wood, Eringate, Bl...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                    Emery, Humberlea  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  St. Phillips, Richview Gardens, Martin Grove G...  43.688905 -79.554724
# 101  Beaumond Heights, Silverstone, Humbergate, Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %% [markdown]
# # Part 3

# %%
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import json # library to handle JSON files
address = 'Toronto, Ontario'

geolocator = geopy.Nominatim(user_agent="ny_explorer", timeout=30)
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto {}, {}.'.format(latitude, longitude))

# create map of Toronto using latitude and longitude values
map_of_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)


# add markers to map based on coordinates of postcode
for lat, lng, neighbourhood in zip(geo_table['Latitude'], geo_table['Longitude'], geo_table['Neighbourhood']):
    label = '{}'.format(neighbourhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_of_toronto)  
    
map_of_toronto
# Out:
# The geograpical coordinate of Toronto 43.653963, -79.387207.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Foursquare ID
CLIENT_ID = "OHPWNGYBB0FL3RDXDPXM4FQAGYL2HJQESEPA55EAACARKOUN" 
#Foursquare Secret
CLIENT_SECRET = "ZYZFOGXO3TH4SJHKUIALEKCX0K1THXXSKUCBVI414GGP3MXR"
# Foursquare API version
VERSION = "20161225"

# %%
LIMIT = 5
radius = 500

location_list = [] # list to store data from Foursquare API requests

for neighbourhood, latitude, longitude in zip(geo_table.Neighbourhood, geo_table.Latitude, geo_table.Longitude):
    
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
    
    data = requests.get(url).json()
    
    # use len() to check if any data within "items" (len = 0 if nothing)
    length = len(data['response']['groups'][0]['items'])
    if length == 0:
        continue # skip the row if nothing is found
    else:
        venue = data['response']['groups'][0]['items'][0]['venue']
        
        # extract info within 'venue'
        name = venue['name']
        lat = venue['location']['lat']
        lon = venue['location']['lng']
        cat = venue['categories'][0]['name']
        
        location_list.append([(neighbourhood, latitude, longitude, name, lat, lon, cat)])

# %%
dat = pd.DataFrame(x for row in location_list for x in row)
dat.columns = ['Neighbourhood','N_Latitude','N_Longitude','Venue','V_Latitude','V_Longitude','category']
dat.head()
# Out:
#                             Neighbourhood  N_Latitude  N_Longitude  \
# 0                          Rouge, Malvern   43.806686   -79.194353
# 1  Port Union, Rouge Hill, Highland Creek   43.784535   -79.160497
# 2       Guildwood, West Hill, Morningside   43.763573   -79.188711
# 3                                  Woburn   43.770992   -79.216917
# 4                               Cedarbrae   43.773136   -79.239476
#
#                    Venue  V_Latitude  V_Longitude              category
# 0                Wendy's   43.807448   -79.199056  Fast Food Restaurant
# 1  Royal Canadian Legion   43.782533   -79.163085                   Bar
# 2      G & G Electronics   43.765309   -79.191537     Electronics Store
# 3              Starbucks   43.770037   -79.221156           Coffee Shop
# 4    Federick Restaurant   43.774697   -79.241142      Hakka Restaurant

# %%
# create map of Toronto using latitude and longitude values
map_dat = folium.Map(location=[latitude, longitude], zoom_start=10)


# add markers to map based on coordinates of postcode
for lat, lng, neighbourhood in zip(dat['V_Latitude'], dat['V_Longitude'], dat['Venue']):
    label = '{}'.format(neighbourhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_dat)  
    
map_dat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
